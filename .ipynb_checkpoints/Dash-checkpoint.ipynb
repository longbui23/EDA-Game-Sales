# %%
from dash import Dash, dcc, html
from dash.dependencies import Input, Output

app = Dash(__name__)

#front-end
app.layout = html.Div({
    html.H2(), #HTML header
    dcc.Dropdown(), #An interactive drop down menu
    dcc.Graph() # A chart that changes based on Dropdown Menu value
})

#back-end
@app.callback(Output(), Input()) #Tiles dropdown to chart
def interactive_chart(input): #create a function accepts a dropdown value as argument
    return output #usually a Plotly chart

#deploy
app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26908\1054908802.py in <module>
#      12
#      13 #back-end
# ---> 14 @app.callback(Output(), Input()) #Tiles dropdown to chart
#      15 def interactive_chart(input): #create a function accepts a dropdown value as argument
#      16     return output #usually a Plotly chart
#
# TypeError: __init__() missing 2 required positional arguments: 'component_id' and 'component_property'

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("vgsales.csv")
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#import packages
from dash import html, dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash

#create app
app = JupyterDash(__name__)

#frontend
app.layout = html.Div(["Pick a Country",
                dcc.Dropdown(options=["USA", "India", "China", "Indonesia", "Nigeria"],
                             value="USA",
                             id="country-dropdown"
                            ),
                       html.H1(id="country-output")
    ])

#backend
@app.callback(
    Output("country-output", "children"),
    Input("country-dropdown", "value")
)
def country_picker(country):
    if not country:
        raise PreventUpdate
    return f"I live in {country}"

#display
if __name__ == "__main__":
    app.run_server(mode="inline")
